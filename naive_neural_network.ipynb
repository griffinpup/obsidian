# %%
#This is a naive implementation similar to the setup at this website.
#https://medium.com/mlreview/a-simple-deep-learning-model-for-stock-price-prediction-using-tensorflow-30505541d877
#The goal is mainly to get a dependable way to scrub and prepare the data we will use.

# %%
#Import all the important ML libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#Import a useful function
from sklearn.preprocessing import MinMaxScaler

# %%
#Read the data
data = pd.read_csv('consolidatedCSV.csv')

# %%
data = data.drop(['DATE'], 1)

# %%
data
# Out:
#               "PRICE"   "QUANTITY"
# 0          300.000000     0.010000
# 1          300.000000     0.010000
# 2          370.000000     0.010000
# 3          370.000000     0.026556
# 4          377.000000     0.010000
# 5          377.875000     2.000000
# 6          378.000000     4.900000
# 7          378.000000     5.200000
# 8          378.000000     0.100000
# 9          378.000000     0.793600
# 10         378.000000     0.010000
# 11         377.900000     0.010000
# 12         378.000000     0.066084
# 13         378.000000     0.010524
# 14         378.000000     0.350000
# 15         377.010000     0.100000
# 16         378.000000     0.010000
# 17         377.100000     0.010000
# 18         378.000000     0.015000
# 19         375.005000     0.117500
# 20         398.000000     0.010000
# 21         360.500000     0.010000
# 22         379.000000     0.050000
# 23         364.990000     0.010000
# 24         360.500000     0.990000
# 25         360.000000     0.100000
# ...
